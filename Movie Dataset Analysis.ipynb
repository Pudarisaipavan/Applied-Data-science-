# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Downloads/imdb_movie_dataset.csv')
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df = df.dropna()
df.isna().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                  838
# Title                 837
# Genre                 189
# Description           838
# Director              524
# Actors                834
# Year                   11
# Runtime (Minutes)      90
# Rating                 50
# Votes                 837
# Revenue (Millions)    789
# Metascore              82
# dtype: int64

# %%
# Display basic statistics for numerical columns
print(df.describe())
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %%
# Calculate correlation matrix for numerical columns
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.312809          -0.254783 -0.243125 -0.303284
# Year               -0.312809  1.000000          -0.101933 -0.145703 -0.362445
# Runtime (Minutes)  -0.254783 -0.101933           1.000000  0.374566  0.399298
# Rating             -0.243125 -0.145703           0.374566  1.000000  0.517452
# Votes              -0.303284 -0.362445           0.399298  0.517452  1.000000
# Revenue (Millions) -0.273170 -0.129198           0.281721  0.217106  0.636833
# Metascore          -0.195909 -0.062303           0.221397  0.672731  0.332674
#
#                     Revenue (Millions)  Metascore
# Rank                         -0.273170  -0.195909
# Year                         -0.129198  -0.062303
# Runtime (Minutes)             0.281721   0.221397
# Rating                        0.217106   0.672731
# Votes                         0.636833   0.332674
# ...

# %%
def plot_movies_per_year(data):
    # Count movies per year and sort by year
    movies_per_year = data['Year'].value_counts().sort_index()

    plt.figure(figsize=(10, 6))
    plt.plot(movies_per_year.index, movies_per_year.values, color='g', marker='o', linestyle='-')
    
    plt.xlabel('Year')
    plt.ylabel('Number of Movies Released')
    plt.title('Number of Movies Released by Year')

    # Annotate the points with the movie counts
    for x, y in zip(movies_per_year.index, movies_per_year.values):
        plt.text(x, y + 0.15, str(y), ha='center', va='bottom', fontsize=9)

    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
plot_movies_per_year(df)

# %%
def plot_top_genres(data):
    # Split the genres and explode them to get a count of each genre
    genre_counts = data['Genre'].str.split(',').explode().value_counts().head(10)
    
    plt.figure(figsize=(10, 6))
    genre_counts.plot(kind='bar', color='skyblue')
    
    plt.xlabel('Genre')
    plt.ylabel('Number of Movies')
    plt.title('Top 10 Most Filmed Genres')
    
    # Annotate each bar with the count value
    for index, value in enumerate(genre_counts):
        plt.text(index, value + 5, str(value), ha='center', va='bottom', fontsize=9)
    
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
plot_top_genres(df)

# %%
def plot_rating_vs_revenue(data):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='Rating', y='Revenue (Millions)', data=data, alpha=0.7, color='coral')
    plt.title('IMDb Rating vs. Revenue')
    plt.xlabel('IMDb Rating')
    plt.ylabel('Revenue (Millions)')
    plt.grid(axis='both', linestyle='--', alpha=0.7)
    plt.show()
plot_rating_vs_revenue(df)
